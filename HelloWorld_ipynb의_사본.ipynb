# %% [markdown]
# <a href="https://colab.research.google.com/github/rosie-ing/Intelligent-Software/blob/main/HelloWorld_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
OPENAI_API_KEY = ""

# %%
# !pip install openai==0.28

# %%
import openai

# %%
openai.api_key = OPENAI_API_KEY
model = "gpt-3.5-turbo-0125"

# %%
query = "프랑스의 수도를 알려줘"
messages=[{
    "role" : "user",
    "content" : query
}]

# %%
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
messages = [{
"role": "system",
"content": "You are a helpful assistant."
}, {
"role": "user",
"content": query
}]

# %%
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
messages = [{
"role": "system",
"content": "You are a humorous assistant."
}, {
"role": "user",
"content": query
}]

# %%
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리야! 에펠탑을 보면 파리라고 적혀 있을 거야. 왕의 궁전, 로맨틱한 강들, 맛있는 크로와상, 이쁜 파리지앵들... 뭐든지 파리에서 시작할 수 있어!

# %%
messages = [{
"role": "system",
"content": "You are a sarcasm assistant."
}, {
"role": "user",
"content": query
}]

# %%
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 네 문제 없어요! 여기는 뉴질랜드 수도가 프랑스라고 아시나요?

# %%
messages = [{
"role": "system",
"content": "You are a pessimistic assistant."
}, {
"role": "user",
"content": query
}]

# %%
response = openai.ChatCompletion.create(
    model = model,
    messages = messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 파리지.하지만 아마 도착했을 때 기분이 별로 좋지 않을 거야.
