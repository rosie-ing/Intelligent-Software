# %% [markdown]
# <a href="https://colab.research.google.com/github/rosie-ing/Intelligent-Software/blob/main/OpenAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
OPENAI_API_KEY = ""

# %%
# !pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (3.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (2025.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->openai==0.28) (4.15.0)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.8.1
#     Uninstalling openai-2.8.1:
#       Successfully uninstalled openai-2.8.1
# Successfully installed openai-0.28.0

# %%
import openai
import time

openai.api_key = OPENAI_API_KEY

max_retries = 3
retry_delay = 5

# %%
for attempt in range(max_retries):
  try:
    response = openai.ChatCompletion.create(
        model = "gpt-4",
        messages=[
            {"role": "system", "content" : "You are a knowledgeable assistant"},
            {"role": "assistant", "content" : "Answer in Korean"},
            {"role": "user", "content" : "What are the health benefits of regular exercise?"}
        ]
    )
    print(response.choices[0].message['content'])
    break
  except openai.error.APIError as e:
    print(f"API error occurred: {e}")
    if attempt < max_retries -1 :
      print(f"Retryint in {retry_delay} seconds...")
      time.sleep(retry_delay)
    else:
      print("Max retries reached. Giving up.")
# Out:
# Regular exercise has numerous health benefits, including:
#
# 1. Weight Control: Exercise can help maintain a healthy weight by burning calories. The more intense the activity, the more calories you burn, which can help prevent excess weight gain or help maintain weight loss.
#
# 2. Disease Prevention: Regular exercise helps prevent or manage a wide range of health problems and conditions, including stroke, metabolic syndrome, type 2 diabetes, depression, a number of types of cancer, arthritis, and many others.
#
# 3. Improved Mood: Physical activity stimulates various brain chemicals that may leave you feeling happier, more relaxed, and less anxious.
#
# 4. Boosts Energy: Regular physical activity can improve your muscle strength and boost your endurance, giving you more energy.
#
# 5. Improves Sleep: Regular physical activity can help you fall asleep faster, get better sleep, and deepen your sleep.
#
# 6. Promotes Better Brain Function: Not only can regular exercise improve mental health and mood, but it can also help with thinking, learning, and judgment skills.
#
# 7. Increased Lifespan: Studies show that physical activity can reduce your risk of dying early from the leading causes of death, like heart disease and some cancers.
#
# Always remember, it's important to consult with a healthcare provider before starting a new exercise program, especially if you have any concerns about your fitness, haven't exercised for a long time, have chronic health problems, such as heart disease, diabetes or arthritis.

# %%
for attempt in range(max_retries):
  try:
    response = openai.ChatCompletion.create(
        model = "gpt-4",
        messages=[
            {"role": "system", "content" : "You are a knowledgeable assistant"},
            {"role": "assistant", "content" : "Answer in Korean"},
            {"role": "user", "content" : "What are the health benefits of regular exercise?"}
        ],
        max_tokens = 200
    )
    print(response.choices[0].message['content'])
    break
  except openai.error.APIError as e:
    print(f"API error occurred: {e}")
    if attempt < max_retries -1 :
      print(f"Retryint in {retry_delay} seconds...")
      time.sleep(retry_delay)
    else:
      print("Max retries reached. Giving up.")
# Out:
# Regular exercise has numerous physical and mental health benefits. Here are some of the key ones:
#
# 1. Weight Control: Exercise can help prevent excess weight gain and help maintain weight loss. The more intense the activity, the more calories you'll burn.
#
# 2. Disease prevention: Regular exercise helps prevent or manage health problems like stroke, metabolic syndrome, high blood pressure, type 2 diabetes, depression, anxiety, many types of cancer, arthritis, and cognitive decline.
#
# 3. Mood improvement: Physical activity stimulates various brain chemicals that may leave you feeling happier, more relaxed, and less anxious.
#
# 4. Energy boost: Regular physical activity can improve muscle strength and boost endurance, giving you more energy.
#
# 5. Better sleep: Regular physical activity can help you fall asleep faster, get better sleep, and deepen your sleep.
#
# 6. Improved brain function: Regular physical activity can improve cognitive function and decrease the risk of cognitive decline.
#
# 7.Aids longevity: Regular exercise can reduce the risk of premature death.
#
# 8

# %%
for attempt in range(max_retries):
  try:
    response = openai.ChatCompletion.create(
        model = "gpt-4",
        messages=[
            {"role": "system", "content" : "You are a knowledgeable assistant"},
            {"role": "assistant", "content" : "Answer in Korean"},
            {"role": "user", "content" : "What are the health benefits of regular exercise?"}
        ],
        temperature = 0.1
    )
    print(response.choices[0].message['content'])
    break
  except openai.error.APIError as e:
    print(f"API error occurred: {e}")
    if attempt < max_retries -1 :
      print(f"Retryint in {retry_delay} seconds...")
      time.sleep(retry_delay)
    else:
      print("Max retries reached. Giving up.")
# Out:
# Regular exercise has numerous health benefits, including:
#
# 1. Improved Heart Health: Regular exercise can help improve your cardiovascular health by reducing risk factors such as high blood pressure, high cholesterol, and obesity.
#
# 2. Weight Management: Exercise can help you maintain a healthy weight or lose weight by increasing your metabolism and burning more calories.
#
# 3. Stronger Bones and Muscles: Weight-bearing and resistance exercises can strengthen your bones and muscles, reducing the risk of osteoporosis and falls.
#
# 4. Improved Mental Health: Exercise can help reduce symptoms of depression and anxiety by releasing endorphins, chemicals in your brain that act as natural mood lifters.
#
# 5. Better Sleep: Regular physical activity can help you fall asleep faster and deepen your sleep.
#
# 6. Increased Lifespan: Regular exercise can help you live longer by reducing the risk of chronic diseases like heart disease, stroke, and certain types of cancer.
#
# 7. Improved Immune Function: Regular moderate-intensity exercise can boost your immune system and help fight off infections.
#
# 8. Enhanced Brain Health: Exercise can improve brain function and protect memory and thinking skills.
#
# 9. Improved Digestion: Regular physical activity can help regulate your digestive system and prevent constipation.
#
# 10. Better Quality of Life: Regular exercise can improve your physical strength and endurance, making daily activities easier and allowing you to stay independent longer.

# %%
for attempt in range(max_retries):
  try:
    response = openai.ChatCompletion.create(
        model = "gpt-4",
        messages=[
            {"role": "system", "content" : "You are a knowledgeable assistant"},
            {"role": "assistant", "content" : "Answer in Korean"},
            {"role": "user", "content" : "What are the health benefits of regular exercise?"}
        ],
        temperature = 0.9
    )
    print(response.choices[0].message['content'])
    break
  except openai.error.APIError as e:
    print(f"API error occurred: {e}")
    if attempt < max_retries -1 :
      print(f"Retryint in {retry_delay} seconds...")
      time.sleep(retry_delay)
    else:
      print("Max retries reached. Giving up.")
# Out:
# Regular exercise offers numerous health benefits, including:
#
# 1. Improved heart health: Exercise strengthens your heart and improves your body's ability to pump blood efficiently, reduces the risk of heart disease and lowers levels of LDL (bad) cholesterol.
#
# 2. Weight control: Engaging in physical activity burns calories and helps prevent excess weight gain.
#
# 3. Stronger bones and muscles: Weight-bearing and resistance exercises can strengthen your bones and muscles, reducing your risk of developing osteoporosis and muscle loss as you age.
#
# 4. Reduced risk of chronic diseases: Regular exercise can help prevent or manage a wide range of health problems, including stroke, type 2 diabetes, depression, certain types of cancer, arthritis and falls.
#
# 5. Improved mood: Physical activity stimulates various brain chemicals, which may leave you feeling happier, more relaxed and less anxious.
#
# 6. Better sleep: Regular physical activity can help you fall asleep faster, get better sleep and deepen your sleep.
#
# 7. Improved brain health: Regular physical activity can improve your thinking, learning, and judgment skills and delay decline of these powers as you age.
#
# 8. Increased lifespan: Regular physical activity can increase your lifespan by keeping your body healthy and warding off chronic diseases.
#
# 9. Boosted energy: Regular physical activity can improve your muscle strength and boost your endurance, giving you more energy.
#
# 10. Better mental health: Regular exercise can have a profoundly positive impact on depression, anxiety, ADHD and more. It also relieves stress, improves memory, helps you sleep better, and boosts your overall mood.
#
# Remember, it's crucial to talk with your doctor before starting a new exercise program, especially if you have any concerns about your fitness, have not been active for a long time, have chronic health problems like heart disease, diabetes or arthritis, or are pregnant.

# %%
for attempt in range(max_retries):
  try:
    response = openai.ChatCompletion.create(
        model = "gpt-4",
        messages=[
            {"role": "system", "content" : "You are a knowledgeable assistant"},
            {"role": "assistant", "content" : "Answer in Korean"},
            {"role": "user", "content" : "What are the health benefits of regular exercise?"}
        ],
        seed = 42
    )
    print(response.choices[0].message['content'])
    break
  except openai.error.APIError as e:
    print(f"API error occurred: {e}")
    if attempt < max_retries -1 :
      print(f"Retryint in {retry_delay} seconds...")
      time.sleep(retry_delay)
    else:
      print("Max retries reached. Giving up.")
# Out:
# Regular exercise has multiple health benefits. Here are some of them:
#
# 1. Improved Heart Health: Regular exercise improves cardiovascular health by reducing risk factors like high cholesterol and blood pressure.
#
# 2. Weight Control: It helps manage weight by burning calories, reducing fat stores and boosting metabolism.
#
# 3. Strengthened Muscles and Bones: Exercise, particularly weight-bearing activities like walking and resistance exercises, build and preserve bone density and muscle mass.
#
# 4. Mental Health Benefits: Exercise can help alleviate symptoms of depression and anxiety due to the release of endorphins which create feelings of happiness and euphoria.
#
# 5. Reduced Risk of Chronic Diseases: Regular physical activity can lower risk for several diseases and health conditions, including heart disease, diabetes, certain cancers, and arthritis.
#
# 6. Improved Sleep: Regular physical activity can help you fall asleep faster and enjoy deeper sleep.
#
# 7. Energy Boost: Regular exercise can increase your energy levels, helping you feel more alert and active during the day.
#
# 8. Improved Brain Health: Regular exercise benefits brain health by improving memory, creativity, and mental sharpness.
#
# Keep in mind, it's important to consult a healthcare professional before starting any new exercise program.

# %%
import openai
import numpy as np

openai.api_key = OPENAI_API_KEY

def get_embeddings(texts):
  response = openai.Embedding.create(
      input=texts,
      model = "text-embedding-ada-002"

  )

  return [embedding['embedding'] for embedding in response['data']]

# %%
color_words = ["red", "blue", "yellow", "green", "violet", "cyan", "black", "white"]

color_embeddings = get_embeddings(color_words)

for word, embedding in zip(color_words, color_embeddings):
  print(f"{word} : {embedding[:5]}...")
  print(len(embedding))
# Out:
# red : [9.326533472631127e-06, -0.02476814016699791, -0.002384250983595848, -0.028791459277272224, -0.021199282258749008]...
# 1536
# blue : [0.005474964156746864, -0.007486246060580015, 0.005678507499396801, -0.03110414557158947, -0.01965053379535675]...
# 1536
# yellow : [0.007661858107894659, -0.024910997599363327, 0.004491548519581556, -0.02860249951481819, -0.01958620548248291]...
# 1536
# green : [0.01546180434525013, -0.010975971817970276, 0.025183379650115967, -0.02092933841049671, -0.005648194346576929]...
# 1536
# violet : [-0.006727131083607674, -0.018318135291337967, 0.0036361967213451862, -0.00567674869671464, -0.021194979548454285]...
# 1536
# cyan : [0.021550633013248444, -0.014010688289999962, 0.008289773017168045, -0.02929886430501938, -0.016149088740348816]...
# 1536
# black : [-0.015103082172572613, -0.031215764582157135, 0.00877943355590105, -0.03691864386200905, -0.01613996922969818]...
# 1536
# white : [0.006292110309004784, -0.02457117661833763, 0.0002028137823799625, -0.014848269522190094, -0.0052642603404819965]...
# 1536

# %%
pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.8.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %%
import openai
import time

openai.api_key = OPENAI_API_KEY


response = openai.files.create(
    file=open("/content/drive/MyDrive/Colab Notebooks/지능형 소프트웨어 강의/mydata.jsonl", "rb"),
    purpose="fine-tune"
)

file_id = response.id
print(f"Uploaded file ID: {file_id}")


response = openai.fine_tuning.jobs.create(
    training_file=file_id,
    model="gpt-4o-mini-2024-07-18"
)

fine_tune_id = response.id
print(f"Fine-tune job ID: {fine_tune_id}")


while True:
    job = openai.fine_tuning.jobs.retrieve(fine_tune_id)
    status = job.status

    print(f"Fine-tune job status: {status}")

    if status in ["succeeded", "failed"]:
        break

    time.sleep(60)


if job.status == "succeeded":
    print("Fine-tuning completed successfully!")
    print("Fine-tuned model:", job.fine_tuned_model)
else:
    print("Fine-tuning failed.")
# Out:
# Uploaded file ID: file-H1WukL21UyuN26GpST7xTG
# Fine-tune job ID: ftjob-1P7hlfLN2L7PI11ZhyYRTVfi
# Fine-tune job status: validating_files
# Fine-tune job status: validating_files
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: running
# Fine-tune job status: succeeded
# Fine-tuning completed successfully!
# Fine-tuned model: ft:gpt-4o-mini-2024-07-18:personal::ChyxDlV4

# %%
import openai

openai.api_key = OPENAI_API_KEY

def edit_text(input_text, instruction):
  response = openai.chat.completions.create(
      model = "gpt-4o-mini",
      messages = [
          {"role": "system", "content": "You are a helpful assistant that edits text."},
          {"role": "user", "content" : f"Please edit the following text : '{input_text}'. Instruction: {instruction}"}
      ]
  )
  return response.choices[0].message.content.strip()

input_text = "The quick brown fox jumps over the lazy dog."
instruction = "Change 'fox' to 'cat' and change the tnse to past."

edited_text = edit_text(input_text, instruction)
print(f"Edited text: {edited_text}")
# Out:
# Edited text: The quick brown cat jumped over the lazy dog.

# %%
import openai

openai.api_key = OPENAI_API_KEY

def moderate_text(input_text):
  response = openai.moderations.create(
      model="omni-moderation-latest",
      input = input_text

  )
  return response

input_texts= [
    "I want to harm myself.",
    "You are an amazing person",
    "Let's meet at 8 PM.",
    "I hate you and I want to hurt you"
]

# %%
for text in input_texts:
  moderation_result = moderate_text(text)

  result = moderation_result.results[0]

  print(f"Input: {text}")
  print(f"Moderation Result: {moderation_result}")
  print("-" * 40)
# Out:
# Input: I want to harm myself.
# Moderation Result: ModerationCreateResponse(id='modr-6141', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=False, harassment_threatening=False, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=True, self_harm_instructions=False, self_harm_intent=True, sexual=False, sexual_minors=False, violence=True, violence_graphic=False, harassment/threatening=False, hate/threatening=False, illicit/violent=False, self-harm/intent=True, self-harm/instructions=False, self-harm=True, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=0.0005689574642911562, harassment_threatening=0.0007684985562636434, hate=1.7952796934677738e-05, hate_threatening=8.888084683809127e-06, illicit=0.005282392090762785, illicit_violent=2.453694805426225e-05, self_harm=0.974646141332934, self_harm_instructions=0.00028151729221049604, self_harm_intent=0.9885670964805034, sexual=8.559006367452268e-05, sexual_minors=6.205049602300744e-06, violence=0.4023404152908457, violence_graphic=0.001610160050623429, harassment/threatening=0.0007684985562636434, hate/threatening=8.888084683809127e-06, illicit/violent=2.453694805426225e-05, self-harm/intent=0.9885670964805034, self-harm/instructions=0.00028151729221049604, self-harm=0.974646141332934, sexual/minors=6.205049602300744e-06, violence/graphic=0.001610160050623429), flagged=True)])
# ----------------------------------------
# Input: You are an amazing person
# Moderation Result: ModerationCreateResponse(id='modr-4410', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=False, harassment_threatening=False, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=False, violence_graphic=False, harassment/threatening=False, hate/threatening=False, illicit/violent=False, self-harm/intent=False, self-harm/instructions=False, self-harm=False, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=0.000804042571983639, harassment_threatening=1.6603846953733614e-05, hate=1.2533751425646102e-05, hate_threatening=3.3405391543507076e-07, illicit=1.2148175280558357e-05, illicit_violent=6.205049602300744e-06, self_harm=0.0004602132171001878, self_harm_instructions=2.4682904407607285e-06, self_harm_intent=0.00021527750928249177, sexual=1.9110431587777674e-05, sexual_minors=2.2827997192887966e-06, violence=0.0011628954264227337, violence_graphic=8.220189478350845e-06, harassment/threatening=1.6603846953733614e-05, hate/threatening=3.3405391543507076e-07, illicit/violent=6.205049602300744e-06, self-harm/intent=0.00021527750928249177, self-harm/instructions=2.4682904407607285e-06, self-harm=0.0004602132171001878, sexual/minors=2.2827997192887966e-06, violence/graphic=8.220189478350845e-06), flagged=False)])
# ----------------------------------------
# Input: Let's meet at 8 PM.
# Moderation Result: ModerationCreateResponse(id='modr-3741', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=False, harassment_threatening=False, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=False, violence_graphic=False, harassment/threatening=False, hate/threatening=False, illicit/violent=False, self-harm/intent=False, self-harm/instructions=False, self-harm=False, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=3.459916031782155e-05, harassment_threatening=1.7130819343483194e-05, hate=8.349627818261147e-06, hate_threatening=9.223470110117277e-07, illicit=3.353501304664781e-05, illicit_violent=2.4923252458203565e-05, self_harm=9.610241549947397e-06, self_harm_instructions=3.535625074174432e-06, self_harm_intent=0.000211865052952336, sexual=4.955359475635505e-05, sexual_minors=6.502816785764437e-06, violence=0.0005600758955536546, violence_graphic=4.832563818725537e-06, harassment/threatening=1.7130819343483194e-05, hate/threatening=9.223470110117277e-07, illicit/violent=2.4923252458203565e-05, self-harm/intent=0.000211865052952336, self-harm/instructions=3.535625074174432e-06, self-harm=9.610241549947397e-06, sexual/minors=6.502816785764437e-06, violence/graphic=4.832563818725537e-06), flagged=False)])
# ----------------------------------------
# Input: I hate you and I want to hurt you
# Moderation Result: ModerationCreateResponse(id='modr-7233', model='omni-moderation-latest', results=[Moderation(categories=Categories(harassment=True, harassment_threatening=True, hate=False, hate_threatening=False, illicit=False, illicit_violent=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=True, violence_graphic=False, harassment/threatening=True, hate/threatening=False, illicit/violent=False, self-harm/intent=False, self-harm/instructions=False, self-harm=False, sexual/minors=False, violence/graphic=False), category_applied_input_types=CategoryAppliedInputTypes(harassment=['text'], harassment_threatening=['text'], hate=['text'], hate_threatening=['text'], illicit=['text'], illicit_violent=['text'], self_harm=['text'], self_harm_instructions=['text'], self_harm_intent=['text'], sexual=['text'], sexual_minors=['text'], violence=['text'], violence_graphic=['text'], harassment/threatening=['text'], hate/threatening=['text'], illicit/violent=['text'], self-harm/intent=['text'], self-harm/instructions=['text'], self-harm=['text'], sexual/minors=['text'], violence/graphic=['text']), category_scores=CategoryScores(harassment=0.8423900605952289, harassment_threatening=0.5711213063336006, hate=0.001195664768288402, hate_threatening=5.0333557545281144e-05, illicit=0.020047808528391945, illicit_violent=0.0020512753426840803, self_harm=0.0005599682011765794, self_harm_instructions=0.00021587874268682574, self_harm_intent=0.0002964673556066361, sexual=0.0007129746438779075, sexual_minors=7.14190139989638e-06, violence=0.8497404009623472, violence_graphic=4.044814978420809e-05, harassment/threatening=0.5711213063336006, hate/threatening=5.0333557545281144e-05, illicit/violent=0.0020512753426840803, self-harm/intent=0.0002964673556066361, self-harm/instructions=0.00021587874268682574, self-harm=0.0005599682011765794, sexual/minors=7.14190139989638e-06, violence/graphic=4.044814978420809e-05), flagged=True)])
# ----------------------------------------

# %%
import openai
import requests
from PIL import Image
from io import BytesIO

openai.api_key = OPENAI_API_KEY

def generate_image(prompt):
  response = openai.Image.create(
      prompt = prompt,
      n=1,
      size="1024x1024"
  )
  image_url = response['data'][0]['url']
  return image_url

def save_image(image_url, filename):
  response = requests.get(image_url)
  image = Image.open(BytesIO(response.content))
  image.save(filename)

prompt="A futuristic cityscape at sunset"

image_url = generate_image(prompt)
print(f"Image URL: {image_url}")

save_image(image_url, "generated_image.png")
print("Image saved as generated_image.png")
# Out:
# Image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-1VH9bovdpfXADsGrWTjyoSMJ/user-eNxIyQlrkjy8uNdXwmaiIlSF/img-gzRgWCmC8GuHKBjZPtZNkW9D.png?st=2025-12-01T12%3A55%3A14Z&se=2025-12-01T14%3A55%3A14Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=cc612491-d948-4d2e-9821-2683df3719f5&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-12-01T07%3A02%3A53Z&ske=2025-12-02T07%3A02%3A53Z&sks=b&skv=2024-08-04&sig=DQi7zB3f/i4FxCwR1G0b2YYH8Yv9dbUx/sqW3pI0%2BEg%3D
# Image saved as generated_image.png

# %%
import openai
import requests
from PIL import Image
from io import BytesIO

openai.api_key = OPENAI_API_KEY

def generate_image(prompt):
  response = openai.Image.create(
    model="dall-e-3",
    prompt="a white siamese cat",
    size="1024x1024",
    quality="standard",
    n=1,
)
  image_url = response['data'][0]['url']
  return image_url

def save_image(image_url, filename):
  response = requests.get(image_url)
  image = Image.open(BytesIO(response.content))
  image.save(filename)

prompt="A white cat"

image_url = generate_image(prompt)
print(f"Image URL: {image_url}")

save_image(image_url, "generated_image.png")
print("Image saved as generated_image.png")
# Out:
# Image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-1VH9bovdpfXADsGrWTjyoSMJ/user-eNxIyQlrkjy8uNdXwmaiIlSF/img-md1yaTze2VlYYQ1llFqHsRUF.png?st=2025-12-01T12%3A55%3A37Z&se=2025-12-01T14%3A55%3A37Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=9346e9b9-5d29-4d37-a0a9-c6f95f09f79d&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-12-01T13%3A54%3A07Z&ske=2025-12-02T13%3A54%3A07Z&sks=b&skv=2024-08-04&sig=DyYcGm8yeEb3kKtxOyXbvRmGCDyTRh3KhtWVPIT3E6g%3D
# Image saved as generated_image.png

# %%
import openai

openai.api_key = OPENAI_API_KEY


def generate_code(prompt, model="gpt-3.5-turbo-instruct", max_tokens = 1000):
  try:
    response = openai.Completion.create(
        model = model,
        prompt = prompt,
        max_tokens = max_tokens,
        temperature = 0,
        n = 1,
        stop = None
    )

    code = response.choices[0].text.strip()
    return code

  except Exception as e :
    print(f"An error occurred : { str(e)}")
    return None

prompt = "Wirte a C code that computes Fibonacci number ussing memoization."

generated_code = generate_code(prompt)

if generated_code:
  print("Generated Code:\n")
  print(generated_code)
else:
  print("Failed to genrate code.")
# Out:
# Generated Code:
#
# #include <stdio.h>
#
# // Function to calculate Fibonacci number using memoization
# int fib(int n, int memo[])
# {
#     // Base cases
#     if (n == 0 || n == 1)
#         return n;
#
#     // Check if the value is already calculated
#     if (memo[n] != -1)
#         return memo[n];
#
#     // Calculate and store the value in the memo array
#     memo[n] = fib(n-1, memo) + fib(n-2, memo);
#
#     // Return the calculated value
#     return memo[n];
# }
#
# int main()
# {
#     int n;
#     printf("Enter the value of n: ");
#     scanf("%d", &n);
#
#     // Initialize the memo array with -1
#     int memo[n+1];
#     for (int i = 0; i <= n; i++)
#         memo[i] = -1;
#
#     // Call the fib function and print the result
#     printf("Fibonacci number at position %d is %d\n", n, fib(n, memo));
#
#     return 0;
# }
#
# /*
# Output:
#
# Enter the value of n: 6
# Fibonacci number at position 6 is 8
# */

# %%
import openai

openai.api_key = OPENAI_API_KEY

upload_response = openai.File.create(
    file = open("/content/drive/MyDrive/Colab Notebooks/지능형 소프트웨어 강의/king-style-chat.jsonl", "rb"),
    purpose='fine-tune'
)
print("Upload Response:")
print(upload_response)
# Out:
# Upload Response:
# {
#   "object": "file",
#   "id": "file-8B1msoeBGrPzGfdBAzG7tf",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 57615,
#   "created_at": 1764597341,
#   "expires_at": null,
#   "status": "processed",
#   "status_details": null
# }

# %%
list_response = openai.File.list()
print("List Response:")
print(list_response)

file_id = upload_response['id']
retrieve_response = openai.File.retrieve(file_id)
print("Retrieve Response:")
print(retrieve_response)

delete_response = openai.File.delete(file_id)
print("Delete Response:")
print(delete_response)
# Out:
# List Response:
# {
#   "object": "list",
#   "data": [
#     {
#       "object": "file",
#       "id": "file-8B1msoeBGrPzGfdBAzG7tf",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 57615,
#       "created_at": 1764597341,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-R1Vp8zpNzuoGWkgEUWYtxJ",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 3128,
#       "created_at": 1764596368,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-6aXdLygF4cHr55jvwrxUkS",
#       "purpose": "fine-tune-results",
#       "filename": "step_metrics.csv",
#       "bytes": 2176,
#       "created_at": 1764116351,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-1pmpzB2cmeBN9QuDn9kLwr",
#       "purpose": "fine-tune",
#       "filename": "mydata.jsonl",
#       "bytes": 3128,
#       "created_at": 1764115179,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-X5VCfAYmf5QwqrJPmi9dST",
#       "purpose": "fine-tune-results",
#       "filename": "step_metrics.csv",
#       "bytes": 2176,
#       "created_at": 1764055420,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-NzmfNqoNoUFKuziaG79wfF",
#       "purpose": "fine-tune-results",
#       "filename": "step_metrics.csv",
#       "bytes": 2144,
#       "created_at": 1764054425,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-Bt9rXyk72KMQZpBMw393xR",
#       "purpose": "fine-tune-results",
#       "filename": "step_metrics.csv",
#       "bytes": 2192,
#       "created_at": 1764054403,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-RudbXWP247r3pggQf8PsKk",
#       "purpose": "fine-tune-results",
#       "filename": "step_metrics.csv",
#       "bytes": 2160,
#       "created_at": 1764054385,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-5yuwuc6evqkppxbnb5wFoD",
#       "purpose": "fine-tune",
#       "filename": "mydata.jsonl",
#       "bytes": 3128,
#       "created_at": 1764053192,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-BPnc2tj7vxBDL5hG9YZDxE",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 3128,
#       "created_at": 1764052410,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-Ec2Q5zgHGpLX2qwZ2AWs91",
#       "purpose": "fine-tune-results",
#       "filename": "step_metrics.csv",
#       "bytes": 2144,
#       "created_at": 1764047341,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-UVxgpJEvxF2hRndseF9jeb",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 3128,
#       "created_at": 1764046327,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     },
#     {
#       "object": "file",
#       "id": "file-CS5RryVCVV5dv1yy2P2Equ",
#       "purpose": "fine-tune",
#       "filename": "file",
#       "bytes": 3128,
#       "created_at": 1764045993,
#       "expires_at": null,
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "has_more": false,
#   "first_id": "file-8B1msoeBGrPzGfdBAzG7tf",
#   "last_id": "file-CS5RryVCVV5dv1yy2P2Equ"
# }
# Retrieve Response:
# {
#   "object": "file",
#   "id": "file-8B1msoeBGrPzGfdBAzG7tf",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 57615,
#   "created_at": 1764597341,
#   "expires_at": null,
#   "status": "processed",
#   "status_details": null
# }
# Delete Response:
# {
#   "object": "file",
#   "deleted": true,
#   "id": "file-8B1msoeBGrPzGfdBAzG7tf"
# }

# %%
import openai
openai.api_key = OPENAI_API_KEY

def transcribe_audio(file_path, model="whisper-1", response_format="json", temperature=0.1, language=None, prompt=None):
  with open(file_path, "rb") as audio_file:
    response = openai.Audio.transcribe(
        file=audio_file,
        model=model,
        response_format=response_format,
        temperature = temperature,
        language = language,
        prompt = prompt
    )
    return response

file_path = "/content/drive/MyDrive/Colab Notebooks/지능형 소프트웨어 강의/Dracula.mp3"

transcription = transcribe_audio(file_path)
print("Transcription Responser:")
print(transcription)
# Out:
# Transcription Responser:
# {
#   "text": "Now that we've found where the enemy's lurking, nothing can stand in our way. Since we are facing the forces of darkness, we must be the cold light of day. We are the lanterns that burn in the lighthouse, the candles in the crypt. We are the light. Let there be light. This is a war and we must be the victors. There's too much to lose if we fail. We'll cross the seas like a band of crusaders, searching for some precious grail. We are the embers that glow in the winter, the diamonds in the mine. Let's take our torches and pray God will show us a sign. Deep in the darkness night, when there's a spark of hope, we must be points of light. He's in the darkness, bright as the dazzling stars in a different sky. And in our cruelest hour, when hope is gone, we'll raise our heads and we'll journey on. When the great battle commences, surely the light will prevail. We will break down his defenses, he will fall. And the sun will rise. Deep in the darkness night, when there's a spark of hope, we must be points of light. He's in the darkness, bright as the dazzling stars in a different sky. And in our cruelest hour, when hope is gone, we'll raise our heads and we'll journey on. www.circlelineartschool.com",
#   "usage": {
#     "type": "duration",
#     "seconds": 116
#   }
# }
